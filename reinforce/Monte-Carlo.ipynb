# %% [markdown]
# ## Imports

# %%
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F     
import torch.optim as optim
from torch.distributions import Categorical
from torch.autograd import Variable
import copy

import gymnasium as gym 
from collections import namedtuple

import matplotlib.pyplot as plt

import pandas as pd

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

# %% [markdown]
# ## Definitions

# %%
SavedAction = namedtuple('SavedAction', ['log_prob', 'value'])
eps = np.finfo(np.float32).eps.item()

# %% [markdown]
# ## Policy Network

# %%
class Policy(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(Policy, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, output_size)

    def forward(self, state):
        """
        Param state is a torch tensor
        """
        x = state
        x = F.relu(self.linear1(x))
        x = F.softmax(self.linear2(x), dim = -1)
            
        return x #Returns Probabilities of each action

# %% [markdown]
# ## Critic in Case of Baseline

# %%
class Critic(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, learning_rate):
        super(Critic, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, output_size)
        self.learning_rate = learning_rate

    def forward(self, state):
        """
        Param state is a torch tensor
        """
        x = state
        x = F.relu(self.linear1(x))
        x = self.linear2(x)

        return x

# %% [markdown]
# ## Agent

# %%
class MCReinforceAgent:
    def __init__(self, env:gym.Env, hidden_size=256, learning_rate = 0.01, gamma=0.99, baseline: Critic = None, toggle_target = False):
        # Params
        self.num_states = env.observation_space.shape[0]
        self.num_actions = env.action_space.n
        self.gamma = gamma
        self.toggle_target = toggle_target
        
        # Policy Network
        self.policy = Policy(self.num_states,hidden_size,self.num_actions).to(device)
        
        if baseline is not None:
            self.baseline = True
            self.critic_network = baseline.to(device)
            self.critic_optimizer = optim.Adam(self.policy.parameters(), lr=self.critic_network.learning_rate)
            self.critic_criterion = nn.MSELoss() 
            if toggle_target:
                self.critic_target = copy.deepcopy(baseline).to(device)
                self.tau = 0.01
                for target_param, param in zip(self.critic_target.parameters(), self.critic_network.parameters()):
                    target_param.data.copy_(param.data)
                    target_param.requires_grad = False
            else:
                self.critic_td_losses = [[],[]]
        else:
            self.baseline = False

        # Action & Reward Buffer (For a given episode)
        self.saved_actions = [] #Elements are NamedTuples
        self.rewards = []

        # Training
        self.optimizer  = optim.Adam(self.policy.parameters(), lr=learning_rate)

    def get_action(self, state):
        state = torch.from_numpy(state).float().to(device)
        probs = self.policy(state)

        if self.baseline:
            state_value = self.critic_network(state)
        else:
            state_value = None

        # create a categorical distribution over the list of probabilities of actions
        m = Categorical(probs)

        # and sample an action using the distribution
        action = m.sample()

        # save to action buffer
        self.saved_actions.append(SavedAction(m.log_prob(action), state_value))

        # the action to take
        return action.item()

    def update(self, returns):
        
        returns = torch.tensor(returns)
        returns = (returns - returns.mean()) / (returns.std() + eps) 
        T = 1
        policy_losses = []
        for (log_prob, value), R in zip(self.saved_actions, returns):
            if self.baseline == False:
                advantage = R 
            else:
                advantage = R - value.item()

            # calculate policy loss
            policy_losses.append(-log_prob * advantage/T)

        # reset gradients
        self.optimizer.zero_grad()

        # sum up all the values of policy_losses
        loss = torch.stack(policy_losses).sum()

        # perform backprop
        loss.backward()
        self.optimizer.step()

        if self.baseline and self.toggle_target == False:
            # reset gradients
            self.critic_optimizer.zero_grad()
            loss = self.critic_criterion(self.critic_td_losses[0][0],self.critic_td_losses[1][0])

            # perform backprop
            loss.backward()
            self.critic_optimizer.step()
            self.critic_td_losses = [[],[]]

        self.saved_actions = []
        self.rewards = []
    
    def update_critic(self,state,reward,next_state,done):
        state = torch.tensor(state).to(device)
        next_state = torch.tensor(next_state).to(device)
        reward = torch.tensor([reward]).to(device)
        if done:
            target = torch.tensor([0]).to(device)
        else:
            if self.toggle_target:
                target = self.critic_target(next_state).to(device)
            else:
                target = self.critic_network(next_state).to(device)
        if not self.toggle_target:
            self.critic_td_losses[0].append(reward + self.gamma*target)
            self.critic_td_losses[1].append(reward + self.critic_network(state))
        else:
            loss = self.critic_criterion(reward + self.gamma*target, self.critic_network(state))
            self.critic_optimizer.zero_grad()
            loss.backward()
            self.critic_optimizer.step()
            for target_param, param in zip(self.critic_target.parameters(), self.critic_network.parameters()):
                target_param.data.copy_(self.tau*param.data + (1-self.tau)*target_param.data)

# %% [markdown]
# ## Run Environment

# %%
def train(env: gym.Env, agent: MCReinforceAgent, running_reward_init, num_episodes, log_interval=10, terminate_on_threshold=False):
    '''
    Returns episode wise returns
    '''
    running_reward = running_reward_init
    returns = []

    for i_episode in range(num_episodes+1):

        # reset environment and episode reward
        state, _ = env.reset()
        ep_reward = 0

        for t in range(1, 10000):

            # select action from policy
            action = agent.get_action(state)

            # take the action
            next_state, reward, done1, done2, _ = env.step(action)
            done = done1 or done2
            if agent.baseline:
                agent.update_critic(state, reward, next_state, done)
            agent.rewards.append(reward)
            ep_reward += reward
            state = next_state
            if done:
                break
        # update cumulative reward
        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward

        # Calculate Returns
        R = 0
        returns_for_agent = []
        for r in agent.rewards[::-1]:
            # calculate the discounted value
            R = r + agent.gamma * R
            returns_for_agent.insert(0, R)
        returns.append(R)
        agent.update(returns_for_agent)

        # log results
        if log_interval is not None:
            if i_episode % log_interval == 0:
                print('Episode {}\tLast reward: {:.4f}\tAverage reward: {:.4f}'.format(
                    i_episode, ep_reward, running_reward))

        # check if we have "solved" the cart pole problem
        if (terminate_on_threshold and running_reward > env.spec.reward_threshold):
            print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward, t))
            break
    return returns

# %% [markdown]
# ## Train and Plot
#
# 5 random seeds + plotting

# %%
def test5(env: gym.Env, agent_params: np.ndarray, critic_params: np.ndarray, running_reward_init, num_episodes, log_interval=10, terminate_on_threshold=False, plot=True, savefile=None, toggle_target = False):
    ''' 
    agent_params = (hidden_size, learning_rate)
    critic_params = (None) if not critic, (hidden_size, learning_rate) otherwise
    '''
    agent_lrs = []
    agent_hls = []
    critic_lrs = []
    critic_hls = []
    avg_regrets = []
    averaged_returns = []
    returns_all_params = []
    for i in range(len(agent_params)):
        print(f"Parameter Set {i+1}:")
        agent_hidden_size = agent_params[i][0]
        agent_learning_rate = agent_params[i][1]
        agent_lrs.append(agent_learning_rate)
        agent_hls.append(agent_hidden_size)
        if critic_params[i] is not None:
            critic_hidden_size = critic_params[i][0]
            critic_learning_rate = critic_params[i][1]
            critic_lrs.append(critic_learning_rate)
            critic_hls.append(critic_hidden_size)
        else:
            critic_lrs.append(np.nan)
            critic_hls.append(np.nan)
        returns = []
        for j in range(5):
            seed = int(np.random.randint(low=1, high=1034300))
            env.reset(seed=seed)
            torch.manual_seed(seed)
            if critic_params[i] is not None:
                critic = Critic(
                    env.observation_space.shape[0], hidden_size=critic_hidden_size, output_size=1, learning_rate=critic_learning_rate)
            else:
                critic = None
            agent = MCReinforceAgent(env, hidden_size=agent_hidden_size,
                                     learning_rate=agent_learning_rate, gamma=0.99, baseline=critic, toggle_target=toggle_target)
            a = train(env, agent, running_reward_init, num_episodes,
                                 log_interval, terminate_on_threshold)
            returns.append(a)
            
        returns_all_params.append(returns)
        averaged_returns.append(np.mean(np.array(returns), axis=0))
        if env.spec.id == 'Acrobot-v1':
            avg_regrets.append(np.sum(
                (1-(0.99)**100)/0.01*-np.ones(len(returns[0])) - (np.mean(np.array(returns), axis=0))))
        elif env.spec.id == 'CartPole-v1':
            avg_regrets.append(np.sum(
                (1-(0.99)**500)/0.01*np.ones(len(returns[0])) - (np.mean(np.array(returns), axis=0))))
    if savefile is not None:
        try:
            df = pd.DataFrame()
            df["agent_lr"] = agent_lrs
            df["agent_hl"] = agent_hls
            df["critic_lr"] = critic_lrs
            df["critic_hl"] = critic_hls
            df["avg_regrets"] = avg_regrets

            df.to_csv(savefile)
        except Exception as e:
            print(f"Error Saving!{e}")

    if plot:
            labels = []
            for i in range(len(agent_params)):
                agent_hidden_size, agent_learning_rate = agent_params[i]
                if critic_params[i] is not None:
                    critic_hidden_size, critic_learning_rate = critic_params[i]
                    label = f'Agent: {agent_hidden_size}-{agent_learning_rate}, Critic: {critic_hidden_size}-{critic_learning_rate}'
                else:
                    label = f'Agent: {agent_hidden_size}-{agent_learning_rate}, No Critic'
                labels.append(label)
                
            if env.spec.id == 'Acrobot-v1':
                plot_returns(returns_all_params, title="Acrobot-v1 with REINFORCE", labels=labels)
            elif env.spec.id == 'CartPole-v1':
                plot_returns(returns_all_params, title="Cartpole-v1 with REINFORCE", labels=labels)

    return returns_all_params


def plot_returns(returns_all_params,labels,title:str = None):
    
    x = np.arange(1, len(returns_all_params[0][0])+1)
    plt.figure()
    for i in range(len(returns_all_params)):
        returns = np.array(returns_all_params[i])
        avg_returns = np.mean(returns, axis=0)
        std_returns = np.std(returns, axis=0)
        label = labels[i] if labels and i < len(labels) else f"run_{i}"
        plt.plot(x, avg_returns, label = label)
        plt.fill_between(x, avg_returns-std_returns,
                         avg_returns+std_returns, alpha=0.5, label = None)

    plt.xlabel('Episode')
    plt.ylabel('Average return per episode')
    if title is not None:
        plt.title(title)
    plt.legend()
    plt.show()

# %% [markdown]
# ### Hyperparameter Tuning:

# %%
## Without baseline
policy_params =[[64,3e-2],[64,3e-3],[64,3e-4]]
no_critic_params = [None for i in policy_params]

#With baseline
critic_params_ = [[32,3e-2],[32,3e-3],[32,3e-4],\
                  [64,3e-2],[64,3e-2],[64,3e-2]]
critic_params = []
for i in critic_params_:
    critic_params += [i]*len(policy_params)
policy_params_baseline = policy_params*len(critic_params_)

# %% [markdown]
# ### Without Baseline

# %%
env = gym.make('CartPole-v1')
test5(env, policy_params,\
            no_critic_params,\
                  0, 1000, log_interval = 100,savefile='cp_wb.csv', plot= True)
# Out:
# Parameter Set 1:
# Episode 0	Last reward: 23.0000	Average reward: 1.1500
# Episode 100	Last reward: 52.0000	Average reward: 50.2640
# Episode 200	Last reward: 236.0000	Average reward: 133.4656
# Episode 300	Last reward: 180.0000	Average reward: 130.5146
# Episode 400	Last reward: 29.0000	Average reward: 47.4134
# Episode 500	Last reward: 31.0000	Average reward: 65.2389
# Episode 600	Last reward: 191.0000	Average reward: 211.9484
# Episode 700	Last reward: 108.0000	Average reward: 116.1027
# Episode 800	Last reward: 423.0000	Average reward: 311.6301
# Episode 900	Last reward: 488.0000	Average reward: 444.3167
# Episode 0	Last reward: 45.0000	Average reward: 2.2500
# Episode 100	Last reward: 10.0000	Average reward: 9.2557
# Episode 200	Last reward: 10.0000	Average reward: 9.3938
# Episode 300	Last reward: 10.0000	Average reward: 9.5054
# Episode 400	Last reward: 9.0000	Average reward: 9.3395
# Episode 500	Last reward: 10.0000	Average reward: 9.4275
# Episode 600	Last reward: 9.0000	Average reward: 9.0787
# Episode 700	Last reward: 10.0000	Average reward: 9.4391
# Episode 800	Last reward: 9.0000	Average reward: 9.3495
# Episode 900	Last reward: 10.0000	Average reward: 9.5163
# Episode 0	Last reward: 27.0000	Average reward: 1.3500
# Episode 100	Last reward: 356.0000	Average reward: 191.0650
# Episode 200	Last reward: 500.0000	Average reward: 248.7167
# Episode 300	Last reward: 500.0000	Average reward: 425.3331
# Episode 400	Last reward: 25.0000	Average reward: 383.5752
# Episode 500	Last reward: 500.0000	Average reward: 478.4968
# Episode 600	Last reward: 24.0000	Average reward: 383.4775
# Episode 700	Last reward: 23.0000	Average reward: 21.0428
# Episode 800	Last reward: 76.0000	Average reward: 226.0737
# Episode 900	Last reward: 13.0000	Average reward: 373.4029
# Episode 0	Last reward: 30.0000	Average reward: 1.5000
# Episode 100	Last reward: 29.0000	Average reward: 43.4209
# Episode 200	Last reward: 500.0000	Average reward: 463.0795
# Episode 300	Last reward: 9.0000	Average reward: 173.6701
# Episode 400	Last reward: 10.0000	Average reward: 10.1529
# Episode 500	Last reward: 10.0000	Average reward: 9.4573
# Episode 600	Last reward: 9.0000	Average reward: 9.2404
# Episode 700	Last reward: 8.0000	Average reward: 9.4229
# Episode 800	Last reward: 10.0000	Average reward: 9.2842
# Episode 900	Last reward: 10.0000	Average reward: 9.4384
# Episode 0	Last reward: 18.0000	Average reward: 0.9000
# Episode 100	Last reward: 94.0000	Average reward: 113.7400
# Episode 200	Last reward: 56.0000	Average reward: 47.1937
# Episode 300	Last reward: 41.0000	Average reward: 50.7743
# Episode 400	Last reward: 45.0000	Average reward: 63.5709
# Episode 500	Last reward: 85.0000	Average reward: 65.4484
# Episode 600	Last reward: 76.0000	Average reward: 60.8215
# Episode 700	Last reward: 65.0000	Average reward: 66.2006
# Episode 800	Last reward: 66.0000	Average reward: 111.0071
# Episode 900	Last reward: 43.0000	Average reward: 64.5269
# Parameter Set 2:
# Episode 0	Last reward: 39.0000	Average reward: 1.9500
# Episode 100	Last reward: 39.0000	Average reward: 46.6762
# Episode 200	Last reward: 63.0000	Average reward: 67.7849
# Episode 300	Last reward: 62.0000	Average reward: 78.5339
# Episode 400	Last reward: 202.0000	Average reward: 231.7698
# Episode 500	Last reward: 460.0000	Average reward: 399.4632
# Episode 600	Last reward: 165.0000	Average reward: 219.3972
# Episode 700	Last reward: 208.0000	Average reward: 189.9811
# Episode 800	Last reward: 500.0000	Average reward: 483.2163
# Episode 900	Last reward: 500.0000	Average reward: 491.7985
# Episode 0	Last reward: 39.0000	Average reward: 1.9500
# Episode 100	Last reward: 17.0000	Average reward: 36.8860
# Episode 200	Last reward: 345.0000	Average reward: 142.7359
# Episode 300	Last reward: 212.0000	Average reward: 212.7855
# Episode 400	Last reward: 293.0000	Average reward: 434.9440
# Episode 500	Last reward: 500.0000	Average reward: 417.7409
# Episode 600	Last reward: 500.0000	Average reward: 330.4211
# Episode 700	Last reward: 136.0000	Average reward: 195.2299
# Episode 800	Last reward: 364.0000	Average reward: 263.5224
# Episode 900	Last reward: 172.0000	Average reward: 190.9939
# Episode 0	Last reward: 55.0000	Average reward: 2.7500
# Episode 100	Last reward: 67.0000	Average reward: 52.1008
# Episode 200	Last reward: 486.0000	Average reward: 242.0479
# Episode 300	Last reward: 500.0000	Average reward: 463.0543
# Episode 400	Last reward: 338.0000	Average reward: 457.5254
# Episode 500	Last reward: 190.0000	Average reward: 214.0162
# Episode 600	Last reward: 500.0000	Average reward: 495.1711
# Episode 700	Last reward: 500.0000	Average reward: 471.7690
# Episode 800	Last reward: 500.0000	Average reward: 490.0682
# Episode 900	Last reward: 399.0000	Average reward: 440.8890
# Episode 0	Last reward: 10.0000	Average reward: 0.5000
# Episode 100	Last reward: 73.0000	Average reward: 99.9601
# Episode 200	Last reward: 500.0000	Average reward: 410.9987
# Episode 300	Last reward: 500.0000	Average reward: 410.8281
# Episode 400	Last reward: 500.0000	Average reward: 448.0540
# Episode 500	Last reward: 500.0000	Average reward: 472.3204
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 env = gym.make('CartPole-v1')
# ----> 2 test5(env, policy_params,\
#       3             no_critic_params,\
#       4                   0, 1000, log_interval = 100,savefile='cp_wb.csv', plot= True)
#
# Cell In[10], line 39, in test5(env, agent_params, critic_params, running_reward_init, num_episodes, log_interval, terminate_on_threshold, plot, savefile, toggle_target)
#      36         critic = None
#      37     agent = MCReinforceAgent(env, hidden_size=agent_hidden_size,
#      38                              learning_rate=agent_learning_rate, gamma=0.99, baseline=critic, toggle_target=toggle_target)
# ---> 39     a = train(env, agent, running_reward_init, num_episodes,
#      40                          log_interval, terminate_on_threshold)
#      41     returns.append(a)
#      43 returns_all_params.append(returns)
#
# Cell In[9], line 17, in train(env, agent, running_reward_init, num_episodes, log_interval, terminate_on_threshold)
#      12 ep_reward = 0
#      14 for t in range(1, 10000):
#      15
#      16     # select action from policy
# ---> 17     action = agent.get_action(state)
#      19     # take the action
#      20     next_state, reward, done1, done2, _ = env.step(action)
#
# Cell In[8], line 51, in MCReinforceAgent.get_action(self, state)
#      48 action = m.sample()
#      50 # save to action buffer
# ---> 51 self.saved_actions.append(SavedAction(m.log_prob(action), state_value))
#      53 # the action to take
#      54 return action.item()
#
# File ~/Desktop/RL-DA6400-assignment_2/.venv/lib/python3.12/site-packages/torch/distributions/categorical.py:140, in Categorical.log_prob(self, value)
#     138 if self._validate_args:
#     139     self._validate_sample(value)
# --> 140 value = value.long().unsqueeze(-1)
#     141 value, log_pmf = torch.broadcast_tensors(value, self.logits)
#     142 value = value[..., :1]
#
# KeyboardInterrupt:

# %%
env = gym.make('Acrobot-v1')
test5(env, policy_params,\
            no_critic_params,\
                  -500, 2000, log_interval = 100,savefile='ac_wb.csv', plot= True)

# %% [markdown]
# ### With Baseline

# %%
env = gym.make('CartPole-v1')
test5(env, policy_params_baseline,\
            critic_params,\
                  0, 2000, log_interval = 100,savefile='cp_b.csv', plot= True)

# %%
env = gym.make('Acrobot-v1')
test5(env, policy_params_baseline,\
            critic_params,\
                  -500, 2000, log_interval = 100,savefile='ac_b.csv', plot= True)

# %% [markdown]
# ### Test Obtained Params

# %%
env = gym.make('Acrobot-v1')
returns_final_cart = test5(env, [[64, 3e-3],[64, 3e-3]],
                       [[32,3e-4],None],
                       -500, 1000, log_interval=10, savefile=None, plot=True, toggle_target=False)
