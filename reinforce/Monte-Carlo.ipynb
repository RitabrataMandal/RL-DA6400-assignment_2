# %% [markdown]
# ## Imports

# %%
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F     
import torch.optim as optim
from torch.distributions import Categorical
from torch.autograd import Variable
import copy

import gymnasium as gym 
from collections import namedtuple

import matplotlib.pyplot as plt

import pandas as pd

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## Definitions

# %%
SavedAction = namedtuple('SavedAction', ['log_prob', 'value'])
eps = np.finfo(np.float32).eps.item()

# %% [markdown]
# ## Policy Network

# %%
class Policy(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(Policy, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, output_size)

    def forward(self, state):
        """
        Param state is a torch tensor
        """
        x = state
        x = F.relu(self.linear1(x))
        x = F.softmax(self.linear2(x), dim = -1)
            
        return x #Returns Probabilities of each action

# %% [markdown]
# ## Critic in Case of Baseline

# %%
class Critic(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, learning_rate):
        super(Critic, self).__init__()
        self.linear1 = nn.Linear(input_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, output_size)
        self.learning_rate = learning_rate

    def forward(self, state):
        """
        Param state is a torch tensor
        """
        x = state
        x = F.relu(self.linear1(x))
        x = self.linear2(x)

        return x

# %% [markdown]
# ## Agent

# %%
class MCReinforceAgent:
    def __init__(self, env:gym.Env, hidden_size=256, learning_rate = 0.01, gamma=0.99, baseline: Critic = None, toggle_target = False):
        # Params
        self.num_states = env.observation_space.shape[0]
        self.num_actions = env.action_space.n
        self.gamma = gamma
        self.toggle_target = toggle_target
        
        # Policy Network
        self.policy = Policy(self.num_states,hidden_size,self.num_actions).to(device)
        
        if baseline is not None:
            self.baseline = True
            self.critic_network = baseline.to(device)
            self.critic_optimizer = optim.Adam(self.policy.parameters(), lr=self.critic_network.learning_rate)
            self.critic_criterion = nn.MSELoss() 
            if toggle_target:
                self.critic_target = copy.deepcopy(baseline).to(device)
                self.tau = 0.01
                for target_param, param in zip(self.critic_target.parameters(), self.critic_network.parameters()):
                    target_param.data.copy_(param.data)
                    target_param.requires_grad = False
            else:
                self.critic_td_losses = [[],[]]
        else:
            self.baseline = False

        # Action & Reward Buffer (For a given episode)
        self.saved_actions = [] #Elements are NamedTuples
        self.rewards = []

        # Training
        self.optimizer  = optim.Adam(self.policy.parameters(), lr=learning_rate)

    def get_action(self, state):
        state = torch.from_numpy(state).float().to(device)
        probs = self.policy(state)

        if self.baseline:
            state_value = self.critic_network(state)
        else:
            state_value = None

        # create a categorical distribution over the list of probabilities of actions
        m = Categorical(probs)

        # and sample an action using the distribution
        action = m.sample()

        # save to action buffer
        self.saved_actions.append(SavedAction(m.log_prob(action), state_value))

        # the action to take
        return action.item()

    def update(self, returns):
        
        returns = torch.tensor(returns)
        returns = (returns - returns.mean()) / (returns.std() + eps) 
        T = 1
        policy_losses = []
        for (log_prob, value), R in zip(self.saved_actions, returns):
            if self.baseline == False:
                advantage = R 
            else:
                advantage = R - value.item()

            # calculate policy loss
            policy_losses.append(-log_prob * advantage/T)

        # reset gradients
        self.optimizer.zero_grad()

        # sum up all the values of policy_losses
        loss = torch.stack(policy_losses).sum()

        # perform backprop
        loss.backward()
        self.optimizer.step()

        if self.baseline and self.toggle_target == False:
            # reset gradients
            self.critic_optimizer.zero_grad()
            loss = self.critic_criterion(self.critic_td_losses[0][0],self.critic_td_losses[1][0])

            # perform backprop
            loss.backward()
            self.critic_optimizer.step()
            self.critic_td_losses = [[],[]]

        self.saved_actions = []
        self.rewards = []
    
    def update_critic(self,state,reward,next_state,done):
        state = torch.tensor(state).to(device)
        next_state = torch.tensor(next_state).to(device)
        reward = torch.tensor([reward]).to(device)
        if done:
            target = torch.tensor([0]).to(device)
        else:
            if self.toggle_target:
                target = self.critic_target(next_state).to(device)
            else:
                target = self.critic_network(next_state).to(device)
        if not self.toggle_target:
            self.critic_td_losses[0].append(reward + self.gamma*target)
            self.critic_td_losses[1].append(reward + self.critic_network(state))
        else:
            loss = self.critic_criterion(reward + self.gamma*target, self.critic_network(state))
            self.critic_optimizer.zero_grad()
            loss.backward()
            self.critic_optimizer.step()
            for target_param, param in zip(self.critic_target.parameters(), self.critic_network.parameters()):
                target_param.data.copy_(self.tau*param.data + (1-self.tau)*target_param.data)

# %% [markdown]
# ## Run Environment

# %%
def train(env: gym.Env, agent: MCReinforceAgent, running_reward_init, num_episodes, log_interval=10, terminate_on_threshold=False):
    '''
    Returns episode wise returns
    '''
    running_reward = running_reward_init
    returns = []

    for i_episode in range(num_episodes):

        # reset environment and episode reward
        state, _ = env.reset()
        ep_reward = 0

        for t in range(1, 10000):

            # select action from policy
            action = agent.get_action(state)

            # take the action
            next_state, reward, done1, done2, _ = env.step(action)
            done = done1 or done2
            if agent.baseline:
                agent.update_critic(state, reward, next_state, done)
            agent.rewards.append(reward)
            ep_reward += reward
            state = next_state
            if done:
                break
        # update cumulative reward
        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward

        # Calculate Returns
        R = 0
        returns_for_agent = []
        for r in agent.rewards[::-1]:
            # calculate the discounted value
            R = r + agent.gamma * R
            returns_for_agent.insert(0, R)
        returns.append(R)
        agent.update(returns_for_agent)

        # log results
        if log_interval is not None:
            if i_episode % log_interval == 0:
                print('Episode {}\tLast reward: {:.4f}\tAverage reward: {:.4f}'.format(
                    i_episode, ep_reward, running_reward))

        # check if we have "solved" the cart pole problem
        if (terminate_on_threshold and running_reward > env.spec.reward_threshold):
            print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward, t))
            break
    return returns

# %% [markdown]
# ## Train and Plot
#
# 5 random seeds + plotting

# %%
def test5(env: gym.Env, agent_params: np.ndarray, critic_params: np.ndarray, running_reward_init, num_episodes, log_interval=10, terminate_on_threshold=False, plot=True, savefile=None, toggle_target = False):
    ''' 
    agent_params = (hidden_size, learning_rate)
    critic_params = (None) if not critic, (hidden_size, learning_rate) otherwise
    '''
    agent_lrs = []
    agent_hls = []
    critic_lrs = []
    critic_hls = []
    avg_regrets = []
    averaged_returns = []
    returns_all_params = []
    for i in range(len(agent_params)):
        print(f"Parameter Set {i+1}:")
        agent_hidden_size = agent_params[i][0]
        agent_learning_rate = agent_params[i][1]
        agent_lrs.append(agent_learning_rate)
        agent_hls.append(agent_hidden_size)
        if critic_params[i] is not None:
            critic_hidden_size = critic_params[i][0]
            critic_learning_rate = critic_params[i][1]
            critic_lrs.append(critic_learning_rate)
            critic_hls.append(critic_hidden_size)
        else:
            critic_lrs.append(np.nan)
            critic_hls.append(np.nan)
        returns = []
        for j in range(5):
            seed = int(np.random.randint(low=1, high=1034300))
            env.reset(seed=seed)
            torch.manual_seed(seed)
            if critic_params[i] is not None:
                critic = Critic(
                    env.observation_space.shape[0], hidden_size=critic_hidden_size, output_size=1, learning_rate=critic_learning_rate)
            else:
                critic = None
            agent = MCReinforceAgent(env, hidden_size=agent_hidden_size,
                                     learning_rate=agent_learning_rate, gamma=0.99, baseline=critic, toggle_target=toggle_target)
            a = train(env, agent, running_reward_init, num_episodes,
                                 log_interval, terminate_on_threshold)
            returns.append(a)
            
        returns_all_params.append(returns)
        averaged_returns.append(np.mean(np.array(returns), axis=0))
        if env.spec.id == 'Acrobot-v1':
            avg_regrets.append(np.sum(
                (1-(0.99)**100)/0.01*-np.ones(len(returns[0])) - (np.mean(np.array(returns), axis=0))))
        elif env.spec.id == 'CartPole-v1':
            avg_regrets.append(np.sum(
                (1-(0.99)**500)/0.01*np.ones(len(returns[0])) - (np.mean(np.array(returns), axis=0))))
    if savefile is not None:
        try:
            df = pd.DataFrame()
            df["agent_lr"] = agent_lrs
            df["agent_hl"] = agent_hls
            df["critic_lr"] = critic_lrs
            df["critic_hl"] = critic_hls
            df["avg_regrets"] = avg_regrets

            df.to_csv(savefile)
        except Exception as e:
            print(f"Error Saving!{e}")

    if plot:
        plot_returns(returns_all_params, title="Acrobot-v1 with REINFORCE", labels=['no_base','base'])

    return returns_all_params


def plot_returns(returns_all_params,labels,title:str = None):
    
    x = np.arange(1, len(returns_all_params[0][0])+1)
    plt.figure()
    for i in range(len(returns_all_params)):
        returns = np.array(returns_all_params[i])
        avg_returns = np.mean(returns, axis=0)
        std_returns = np.std(returns, axis=0)
        plt.plot(x, avg_returns, label = labels[i])
        plt.fill_between(x, avg_returns-std_returns,
                         avg_returns+std_returns, alpha=0.5, label = None)

    plt.xlabel('Episode')
    plt.ylabel('Average return per episode')
    if title is not None:
        plt.title(title)
    plt.legend()
    plt.show()

# %% [markdown]
# ### Hyperparameter Tuning:

# %%
## Without baseline
policy_params =[[64,3e-2],[64,3e-3],[64,3e-4]]
no_critic_params = [None for i in policy_params]

#With baseline
critic_params_ = [[32,3e-2],[32,3e-3],[32,3e-4],\
                  [64,3e-2],[64,3e-2],[64,3e-2]]
critic_params = []
for i in critic_params_:
    critic_params += [i]*len(policy_params)
policy_params_baseline = policy_params*len(critic_params_)

# %% [markdown]
# ### Without Baseline

# %%
env = gym.make('CartPole-v1')
test5(env, policy_params,\
            no_critic_params,\
                  0, 1000, log_interval = 100,savefile='cp_wb.csv', plot= True)
# Out:
# Parameter Set 1:
# Episode 0	Last reward: 14.00	Average reward: 0.70
# Episode 100	Last reward: 166.00	Average reward: 96.32
# Episode 200	Last reward: 38.00	Average reward: 32.62
# Episode 300	Last reward: 57.00	Average reward: 59.28
# Episode 400	Last reward: 39.00	Average reward: 85.43
# Episode 500	Last reward: 56.00	Average reward: 55.68
# Episode 600	Last reward: 310.00	Average reward: 231.85
# Episode 700	Last reward: 95.00	Average reward: 95.42
# Episode 800	Last reward: 74.00	Average reward: 67.75
# Episode 900	Last reward: 76.00	Average reward: 100.10
# Episode 0	Last reward: 26.00	Average reward: 1.30
# Episode 100	Last reward: 9.00	Average reward: 42.76
# Episode 200	Last reward: 9.00	Average reward: 9.55
# Episode 300	Last reward: 10.00	Average reward: 9.32
# Episode 400	Last reward: 8.00	Average reward: 9.40
# Episode 500	Last reward: 8.00	Average reward: 9.41
# Episode 600	Last reward: 12.00	Average reward: 23.51
# Episode 700	Last reward: 111.00	Average reward: 43.60
# Episode 800	Last reward: 83.00	Average reward: 56.86
# Episode 900	Last reward: 99.00	Average reward: 114.03
# Episode 0	Last reward: 15.00	Average reward: 0.75
# Episode 100	Last reward: 9.00	Average reward: 11.70
# Episode 200	Last reward: 8.00	Average reward: 9.26
# Episode 300	Last reward: 9.00	Average reward: 9.16
# Episode 400	Last reward: 9.00	Average reward: 9.09
# Episode 500	Last reward: 8.00	Average reward: 9.25
# Episode 600	Last reward: 10.00	Average reward: 9.36
# Episode 700	Last reward: 8.00	Average reward: 9.43
# Episode 800	Last reward: 10.00	Average reward: 9.47
# Episode 900	Last reward: 9.00	Average reward: 9.32
# Episode 0	Last reward: 29.00	Average reward: 1.45
# Episode 100	Last reward: 158.00	Average reward: 131.07
# Episode 200	Last reward: 12.00	Average reward: 82.63
# Episode 300	Last reward: 88.00	Average reward: 61.44
# Episode 400	Last reward: 37.00	Average reward: 42.23
# Episode 500	Last reward: 47.00	Average reward: 35.31
# Episode 600	Last reward: 303.00	Average reward: 376.99
# Episode 700	Last reward: 133.00	Average reward: 121.23
# Episode 800	Last reward: 93.00	Average reward: 98.22
# Episode 900	Last reward: 86.00	Average reward: 127.39
# Episode 0	Last reward: 21.00	Average reward: 1.05
# Episode 100	Last reward: 23.00	Average reward: 60.71
# Episode 200	Last reward: 27.00	Average reward: 53.67
# Episode 300	Last reward: 50.00	Average reward: 54.45
# Episode 400	Last reward: 36.00	Average reward: 33.85
# Episode 500	Last reward: 56.00	Average reward: 47.83
# Episode 600	Last reward: 76.00	Average reward: 96.11
# Episode 700	Last reward: 28.00	Average reward: 30.46
# Episode 800	Last reward: 30.00	Average reward: 32.90
# Episode 900	Last reward: 22.00	Average reward: 15.95
# Parameter Set 2:
# Episode 0	Last reward: 12.00	Average reward: 0.60
# Episode 100	Last reward: 101.00	Average reward: 48.57
# Episode 200	Last reward: 95.00	Average reward: 174.32
# Episode 300	Last reward: 140.00	Average reward: 135.93
# Episode 400	Last reward: 500.00	Average reward: 489.52
# Episode 500	Last reward: 238.00	Average reward: 477.47
# Episode 600	Last reward: 500.00	Average reward: 499.57
# Episode 700	Last reward: 135.00	Average reward: 216.09
# Episode 800	Last reward: 147.00	Average reward: 134.57
# Episode 900	Last reward: 135.00	Average reward: 140.92
# Episode 0	Last reward: 13.00	Average reward: 0.65
# Episode 100	Last reward: 48.00	Average reward: 28.60
# Episode 200	Last reward: 97.00	Average reward: 150.41
# Episode 300	Last reward: 270.00	Average reward: 394.00
# Episode 400	Last reward: 500.00	Average reward: 470.97
# Episode 500	Last reward: 500.00	Average reward: 499.73
# Episode 600	Last reward: 500.00	Average reward: 484.85
# Episode 700	Last reward: 500.00	Average reward: 492.42
# Episode 800	Last reward: 500.00	Average reward: 498.68
# Episode 900	Last reward: 498.00	Average reward: 491.37
# Episode 0	Last reward: 41.00	Average reward: 2.05
# Episode 100	Last reward: 167.00	Average reward: 69.14
# Episode 200	Last reward: 500.00	Average reward: 310.34
# Episode 300	Last reward: 500.00	Average reward: 484.96
# Episode 400	Last reward: 500.00	Average reward: 481.87
# Episode 500	Last reward: 500.00	Average reward: 469.12
# Episode 600	Last reward: 500.00	Average reward: 494.45
# Episode 700	Last reward: 500.00	Average reward: 481.47
# Episode 800	Last reward: 124.00	Average reward: 153.37
# Episode 900	Last reward: 500.00	Average reward: 477.14
# Episode 0	Last reward: 17.00	Average reward: 0.85
# Episode 100	Last reward: 42.00	Average reward: 51.38
# Episode 200	Last reward: 116.00	Average reward: 125.85
# Episode 300	Last reward: 103.00	Average reward: 110.84
# Episode 400	Last reward: 294.00	Average reward: 329.29
# Episode 500	Last reward: 83.00	Average reward: 154.49
# Episode 600	Last reward: 342.00	Average reward: 369.82
# Episode 700	Last reward: 500.00	Average reward: 476.88
# Episode 800	Last reward: 500.00	Average reward: 483.46
# Episode 900	Last reward: 500.00	Average reward: 489.67
# Episode 0	Last reward: 20.00	Average reward: 1.00
# Episode 100	Last reward: 33.00	Average reward: 37.63
# Episode 200	Last reward: 137.00	Average reward: 77.23
# Episode 300	Last reward: 143.00	Average reward: 151.87
# Episode 400	Last reward: 500.00	Average reward: 416.55
# Episode 500	Last reward: 500.00	Average reward: 467.24
# Episode 600	Last reward: 500.00	Average reward: 441.52
# Episode 700	Last reward: 500.00	Average reward: 482.11
# Episode 800	Last reward: 500.00	Average reward: 491.43
# Episode 900	Last reward: 500.00	Average reward: 497.12
# Parameter Set 3:
# Episode 0	Last reward: 13.00	Average reward: 0.65
# Episode 100	Last reward: 26.00	Average reward: 30.65
# Episode 200	Last reward: 29.00	Average reward: 28.05
# Episode 300	Last reward: 16.00	Average reward: 40.63
# Episode 400	Last reward: 44.00	Average reward: 41.44
# Episode 500	Last reward: 48.00	Average reward: 49.40
# Episode 600	Last reward: 65.00	Average reward: 48.34
# Episode 700	Last reward: 73.00	Average reward: 67.08
# Episode 800	Last reward: 73.00	Average reward: 79.22
# Episode 900	Last reward: 267.00	Average reward: 107.37
# Episode 0	Last reward: 17.00	Average reward: 0.85
# Episode 100	Last reward: 32.00	Average reward: 22.88
# Episode 200	Last reward: 12.00	Average reward: 23.78
# Episode 300	Last reward: 24.00	Average reward: 31.08
# Episode 400	Last reward: 47.00	Average reward: 39.45
# Episode 500	Last reward: 30.00	Average reward: 32.60
# Episode 600	Last reward: 32.00	Average reward: 45.01
# Episode 700	Last reward: 57.00	Average reward: 52.52
# Episode 800	Last reward: 34.00	Average reward: 53.66
# Episode 900	Last reward: 46.00	Average reward: 66.56
# Episode 0	Last reward: 29.00	Average reward: 1.45
# Episode 100	Last reward: 14.00	Average reward: 23.03
# Episode 200	Last reward: 28.00	Average reward: 23.13
# Episode 300	Last reward: 51.00	Average reward: 28.19
# Episode 400	Last reward: 69.00	Average reward: 37.64
# Episode 500	Last reward: 15.00	Average reward: 42.30
# Episode 600	Last reward: 126.00	Average reward: 55.27
# Episode 700	Last reward: 79.00	Average reward: 65.55
# Episode 800	Last reward: 102.00	Average reward: 95.48
# Episode 900	Last reward: 160.00	Average reward: 112.90
# Episode 0	Last reward: 77.00	Average reward: 3.85
# Episode 100	Last reward: 21.00	Average reward: 27.71
# Episode 200	Last reward: 20.00	Average reward: 24.92
# Episode 300	Last reward: 21.00	Average reward: 28.03
# Episode 400	Last reward: 22.00	Average reward: 34.33
# Episode 500	Last reward: 37.00	Average reward: 44.42
# Episode 600	Last reward: 56.00	Average reward: 50.03
# Episode 700	Last reward: 28.00	Average reward: 44.88
# Episode 800	Last reward: 53.00	Average reward: 61.94
# Episode 900	Last reward: 136.00	Average reward: 64.86
# Episode 0	Last reward: 18.00	Average reward: 0.90
# Episode 100	Last reward: 39.00	Average reward: 22.85
# Episode 200	Last reward: 27.00	Average reward: 24.41
# Episode 300	Last reward: 76.00	Average reward: 30.57
# Episode 400	Last reward: 15.00	Average reward: 24.58
# Episode 500	Last reward: 13.00	Average reward: 41.36
# Episode 600	Last reward: 33.00	Average reward: 40.84
# Episode 700	Last reward: 33.00	Average reward: 42.35
# Episode 800	Last reward: 34.00	Average reward: 56.82
# Episode 900	Last reward: 109.00	Average reward: 65.39
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 env = gym.make('CartPole-v1')
# ----> 2 test5(env, policy_params,\
#       3             no_critic_params,\
#       4                   0, 1000, log_interval = 100,savefile='cp_wb.csv', plot= True)
#
# Cell In[8], line 65, in test5(env, agent_params, critic_params, running_reward_init, num_episodes, log_interval, terminate_on_threshold, plot, savefile, toggle_target)
#      62         print(f"Error Saving!{e}")
#      64 if plot:
# ---> 65     plot_returns(returns_all_params, title="Acrobot-v1 with REINFORCE", labels=['no_base','base'])
#      67 return returns_all_params
#
# Cell In[8], line 78, in plot_returns(returns_all_params, labels, title)
#      76     avg_returns = np.mean(returns, axis=0)
#      77     std_returns = np.std(returns, axis=0)
# ---> 78     plt.plot(x, avg_returns, label = labels[i])
#      79     plt.fill_between(x, avg_returns-std_returns,
#      80                      avg_returns+std_returns, alpha=0.5, label = None)
#      82 plt.xlabel('Episode')
#
# IndexError: list index out of range

# %%
env = gym.make('Acrobot-v1')
test5(env, policy_params,\
            no_critic_params,\
                  -500, 2000, log_interval = 100,savefile='ac_wb.csv', plot= True)

# %% [markdown]
# ### With Baseline

# %%
env = gym.make('CartPole-v1')
test5(env, policy_params_baseline,\
            critic_params,\
                  0, 2000, log_interval = 100,savefile='cp_b.csv', plot= True)

# %%
env = gym.make('Acrobot-v1')
test5(env, policy_params_baseline,\
            critic_params,\
                  -500, 2000, log_interval = 100,savefile='ac_b.csv', plot= True)

# %% [markdown]
# ### Test Obtained Params

# %%
env = gym.make('Acrobot-v1')
returns_final_cart = test5(env, [[64, 3e-3],[64, 3e-3]],
                       [[32,3e-4],None],
                       -500, 1000, log_interval=10, savefile=None, plot=True, toggle_target=False)
